# %%
import os

files = os.listdir("gifs/")

# %%
out = """
# Double pendulum gifs


"""

fams = []
for file in files:
    traj = file.removesuffix(".gif")
    if traj.endswith("-0"):
        out += f"\n\n\n\n## {traj.removesuffix("-0")}"
    out += f"\n\n![txt](gifs/{file})"

# %%
with open("readme.md", "w") as file:
    file.write(out)
